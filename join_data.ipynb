# %%
import pandas as pd
from sql_client import SqlClient

# %%
SERVER_NAME = "teamseven.ct4lx0aqwcg9.ca-central-1.rds.amazonaws.com"
DATABASE_NAME = "eicu_demo"
USERNAME = "admin"
PASSWORD = "jXGiWT5FqVTyMQHXa74c"
s = SqlClient(SERVER_NAME, DATABASE_NAME, USERNAME, PASSWORD)

# %%
diag = s.select("diagnosis_squashed").set_index('patientunitstayid')
lab = s.select("lab_flat").set_index('patientunitstayid')
patient = s.select("patient").set_index('patientunitstayid')

# %%
joined = diag.join([lab, patient], how="inner")

# %%
joined.drop('labname', inplace=True, axis=1)

# %%
joined
# Out:
#                                                             icd9code bands  \
# patientunitstayid
# 143870                                       No Code;No Code;No Code  None
# 145427             038.9, A41.9;No Code;No Code;562.11, K57.32;56...   1.0
# 151179             276.2, E87.2;785.52, R65.21;No Code;275.41, E8...   3.6
# 151867                                               No Code;No Code  None
# 151900             518.82;No Code;486, J18.9;790.6, R73.9;584.9, ...  None
# ...                                                              ...   ...
# 3351763                518.81, J96.00;No Code;518.81, J96.00;No Code  None
# 3352230            997.1, I97.89;No Code;410.90, I21.3;410.90, I2...  None
# 3352231                                                410.90, I21.3  None
# 3352333            560.9, K56.60;518.82;518.82;291.81, F10.239;56...  None
# 3353113            401.9, I10;780.09, 980.0, E980.2, T51.0;401.9,...  None
#
# ...

# %%
joined.to_csv('joined_data.csv')
